# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# # FILE #1

# %%
df_agri1 = pd.read_csv("C:\\Users\\Acer\\Desktop\\API_AG.CON.FERT.ZS_DS2_en_csv_v2_4772365\\data.csv")

# %%
df_agri1.head(5)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 1  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 3  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 4  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
#
#        1961      1962      1963      1964      1965  ...       2012  \
# 0       NaN       NaN       NaN       NaN       NaN  ...        NaN
# 1       NaN       NaN       NaN       NaN       NaN  ...  19.063658
# ...

# %%
df_agri1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df_agri1.describe()
# Out:
#        1960         1961        1962        1963        1964        1965  \
# count   0.0   128.000000  128.000000  128.000000  132.000000  132.000000
# mean    NaN    58.413274   60.438052   63.739000   65.776362   66.789514
# std     NaN   130.656507  116.199935  112.768229  115.125591  112.435964
# min     NaN     0.013653    0.051546    0.035914    0.008696    0.008697
# 25%     NaN     2.535930    2.767794    3.109693    2.872474    2.996075
# 50%     NaN    11.233730   12.141368   14.607351   14.962226   16.772130
# 75%     NaN    65.311780   69.211910   78.112710   83.787960   84.788226
# max     NaN  1166.666667  750.000000  620.222397  603.825222  625.000000
#
#              1966        1967         1968         1969  ...         2012  \
# count  142.000000  145.000000   145.000000   147.000000  ...   211.000000
# mean    67.376135   72.897920    81.275007    85.013015  ...   172.098646
# std    119.587027  128.393786   147.503131   154.892758  ...   390.419311
# ...

# %%
df_agri1
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 1    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 2    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 3    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# ...

# %%
df_agri1['Total for country'] = df_agri1.sum(axis=1)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15616\3776021533.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_agri1['Total for country'] = df_agri1.sum(axis=1)

# %%
df_agri1['Average for country'] = df_agri1['Total for country']/62

# %%
df_agri1
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 1    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 2    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 3    Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# ...

# %%
df_agri1.to_csv("df_agri1_cleaned.csv", index= False)

# %% [markdown]
# # FILE #2

# %%
df_agri2 = pd.read_csv("C:\\Users\\Acer\\Desktop\\API_AG.CON.FERT.ZS_DS2_en_csv_v2_4772365\\Metadata_Country_API_AG.CON.FERT.ZS_DS2_en_csv_v2_4772365.csv")

# %%
df_agri2
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_agri2 = df_agri2.drop(['Unnamed: 5'], axis=1)

# %%
df_agri2
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_agri2.dropna(subset=['IncomeGroup'], inplace =True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15616\2295454369.py in <module>
# ----> 1 df_agri2.dropna(subset=['IncomeGroup'], inplace =True)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
df_agri2.dropna(subset=['IncomeGroup'], inplace=True)

# %%
df_agri2
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_agri2
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 2            AFG                  South Asia           Low income
# 4            AGO          Sub-Saharan Africa  Lower middle income
# 5            ALB       Europe & Central Asia  Upper middle income
# 6            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName
# 0                                                  NaN         Aruba
# ...

# %%
df_agri2.to_csv("df_agri2_cleaned.csv", index= False)

# %% [markdown]
# # FILE #3

# %%
df_agri3 = pd.read_csv("C:\\Users\\Acer\\Desktop\\API_AG.CON.FERT.ZS_DS2_en_csv_v2_4772365\\Metadata_Country_API_AG.CON.FERT.ZS_DS2_en_csv_v2_4772365.csv")

# %%
df_agri3
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_agri3 = df_agri3.drop(['Unnamed: 5'], axis=1)

# %%
df_agri3 = df_agri3[df_agri3['IncomeGroup'].isna()]

# %%
df_agri3
# Out:
#     Country Code                     Region IncomeGroup  \
# 1            AFE                        NaN         NaN
# 3            AFW                        NaN         NaN
# 7            ARB                        NaN         NaN
# 36           CEB                        NaN         NaN
# 49           CSS                        NaN         NaN
# 61           EAP                        NaN         NaN
# 62           EAR                        NaN         NaN
# 63           EAS                        NaN         NaN
# 64           ECA                        NaN         NaN
# 65           ECS                        NaN         NaN
# 68           EMU                        NaN         NaN
# 73           EUU                        NaN         NaN
# 74           FCS                        NaN         NaN
# 95           HIC                        NaN         NaN
# 98           HPC                        NaN         NaN
# 102          IBD                        NaN         NaN
# ...

# %%
df_agri3.to_csv("df_agri3_cleaned.csv", index= False)
